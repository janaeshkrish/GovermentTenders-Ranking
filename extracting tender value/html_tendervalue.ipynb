# %%
import pandas as pd

#To display entire column in dataframe
pd.set_option("display.max_rows", None, "display.max_columns", None)

datas = pd.read_html('71090547.html')

print(len(datas))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-4c590c6105bb> in <module>
#       4 pd.set_option("display.max_rows", None, "display.max_columns", None)
#       5
# ----> 6 datas = pd.read_html('71090547.html')
#       7
#       8 print(len(datas))
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083         )
#    1084     validate_header_arg(header)
# -> 1085     return _parse(
#    1086         flavor=flavor,
#    1087         io=io,
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913             break
#     914     else:
# --> 915         raise retained
#     916
#     917     ret = []
#
# ...

# %%
datas[0].columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
datas[0]
# Out:
#                                                     0  \
# 0   Basic Details Organisation Chain State Project...
# 1                                       Basic Details
# 2                                                 NaN
# 3   Organisation Chain State Project Directorate (...
# 4                                  Organisation Chain
# 5                             Tender Reference Number
# 6                                           Tender ID
# 7                                         Tender Type
# 8                                     Tender Category
# 9                General Technical Evaluation Allowed
# 10                                       Payment Mode
# 11                  Is Multi Currency Allowed For Fee
# 12                                                NaN
# 13  Payment Instruments Online Bankers S.No Bank N...
# 14  Payment Instruments Online Bankers S.No Bank N...
# 15                                Payment Instruments
# ...

# %%
#first_table.loc[first_table[0].str.find('Tender Value in')]

# %%
first_table = datas[0]
tender_value = first_table.loc[first_table[0] == 'Tender Value in â¹']
tender_value
# Out:
#                       0        1                 2  \
# 60  Tender Value in â¹  1500000  Product Category
#
#                              3             4    5
# 60  Electrical Goods/Equipment  Sub category  NaN

# %%
tender_value[1]
# Out:
# 60    1500000
# Name: 1, dtype: object
